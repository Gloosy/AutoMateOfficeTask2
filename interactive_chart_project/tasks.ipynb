# %%
# tasks.ipynb

from celery import Celery
import os

# Configuration for Celery
celery = Celery('interactive_chart_project', broker='redis://localhost:6379/0')

@celery.task
def weekly_report(api_key, file_path):
    """Task to generate the weekly report."""
    from fetch_data import fetch_data_from_gemini
    from process_data import process_data
    from generate_chart import generate_chart

    # Fetch data from Gemini API
    gemini_data = fetch_data_from_gemini(api_key)

    # Load and process local data
    local_data = process_data(file_path)

    # Generate the chart
    chart = generate_chart(local_data)

    # Save the chart to HTML
    chart_file = 'Financial_Data_By_Country.html'
    chart.write_html(chart_file)

    print("Report generated and saved as Financial_Data_By_Country.html")

# Example usage
api_key = "AIzaSyBb37uBqbYw919HIJsBR6ZsiRzYlWoLQws"  # Replace with your actual API key
file_path = 'Financial_Data.xlsx'
weekly_report.apply_async(args=[api_key, file_path], countdown=60 * 60 * 24 * 7)  # Schedule weekly
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Sreynoch\miniforge3\envs\tgi\lib\site-packages\kombu\utils\functional.py:32, in ChannelPromise.__call__(self)
#      31 try:
# ---> 32     return self.__value__
#      33 except AttributeError:
#
# AttributeError: 'ChannelPromise' object has no attribute '__value__'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# File c:\Users\Sreynoch\miniforge3\envs\tgi\lib\site-packages\kombu\transport\virtual\base.py:951, in Transport.create_channel(self, connection)
#     950 try:
# --> 951     return self._avail_channels.pop()
#     952 except IndexError:
#
# IndexError: pop from empty list
#
# During handling of the above exception, another exception occurred:
#
# ...
