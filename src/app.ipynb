# %%
import streamlit as st
from config import CHARTS_FOLDER, REPORTS_FOLDER, EMAIL_LIST_PATH, MAIL_MERGE_TEMPLATE_PATH
from functions.pdf import convert_pdf
from functions.email import send_email
from functions.excel import interactive_excel, create_project_structure_template
from functions.powerpoint import create_powerpoint
from functions.mail_merge import mail_merge
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import streamlit as st
#       2 from config import CHARTS_FOLDER, REPORTS_FOLDER, EMAIL_LIST_PATH, MAIL_MERGE_TEMPLATE_PATH
#       3 from functions.pdf import convert_pdf
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
pip install streamlit
# Out:
# Collecting streamlitNote: you may need to restart the kernel to use updated packages.
#
#   Downloading streamlit-1.38.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from streamlit) (10.4.0)
# Collecting protobuf<6,>=3.20 (from streamlit)
#   Downloading protobuf-5.28.2-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-17.0.0-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from streamlit) (2.32.2)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Downloading rich-13.8.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from streamlit) (8.2.3)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from streamlit) (4.11.0)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from streamlit) (6.4.1)
# Collecting watchdog<5,>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.2-py3-none-win_amd64.whl.metadata (38 kB)
# Requirement already satisfied: jinja2 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Collecting narwhals>=1.5.2 (from altair<6,>=4.0->streamlit)
#   Downloading narwhals-1.8.2-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: colorama in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\sreynoch\miniforge3\envs\tgi\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Downloading streamlit-1.38.0-py2.py3-none-any.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.7 MB 2.6 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/8.7 MB 3.2 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/8.7 MB 4.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.0/8.7 MB 6.0 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/8.7 MB 7.5 MB/s eta 0:00:01
#    -------- ------------------------------- 2.0/8.7 MB 8.4 MB/s eta 0:00:01
#    -------- ------------------------------- 2.0/8.7 MB 8.4 MB/s eta 0:00:01
#    --------- ------------------------------ 2.1/8.7 MB 5.8 MB/s eta 0:00:02
#    ------------- -------------------------- 3.0/8.7 MB 7.4 MB/s eta 0:00:01
#    --------------- ------------------------ 3.3/8.7 MB 7.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.6/8.7 MB 7.5 MB/s eta 0:00:01
#    -------------------- ------------------- 4.4/8.7 MB 8.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.1/8.7 MB 8.7 MB/s eta 0:00:01
#    -------------------------- ------------- 5.8/8.7 MB 9.3 MB/s eta 0:00:01
#    ------------------------------ --------- 6.7/8.7 MB 10.0 MB/s eta 0:00:01
#    ------------------------------ --------- 6.7/8.7 MB 10.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.8/8.7 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  8.6/8.7 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  8.6/8.7 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  8.6/8.7 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 8.2 MB/s eta 0:00:00
# Downloading altair-5.4.1-py3-none-any.whl (658 kB)
#    ---------------------------------------- 0.0/658.1 kB ? eta -:--:--
#    ---------------------------- ---------- 481.3/658.1 kB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 658.1/658.1 kB 7.0 MB/s eta 0:00:00
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Downloading protobuf-5.28.2-cp310-abi3-win_amd64.whl (431 kB)
#    ---------------------------------------- 0.0/431.5 kB ? eta -:--:--
#    --------------------------------------  430.1/431.5 kB 13.5 MB/s eta 0:00:01
#    ---------------------------------------- 431.5/431.5 kB 6.8 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-win_amd64.whl (25.1 MB)
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#     --------------------------------------- 0.5/25.1 MB 10.9 MB/s eta 0:00:03
#    - -------------------------------------- 1.0/25.1 MB 10.6 MB/s eta 0:00:03
#    -- ------------------------------------- 1.5/25.1 MB 10.4 MB/s eta 0:00:03
#    --- ------------------------------------ 2.0/25.1 MB 10.4 MB/s eta 0:00:03
#    --- ------------------------------------ 2.3/25.1 MB 9.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.8/25.1 MB 9.5 MB/s eta 0:00:03
#    ----- ---------------------------------- 3.3/25.1 MB 9.6 MB/s eta 0:00:03
#    ------ --------------------------------- 3.9/25.1 MB 9.3 MB/s eta 0:00:03
#    ------- -------------------------------- 4.4/25.1 MB 9.4 MB/s eta 0:00:03
#    ------- -------------------------------- 5.0/25.1 MB 9.6 MB/s eta 0:00:03
#    -------- ------------------------------- 5.6/25.1 MB 9.6 MB/s eta 0:00:03
#    --------- ------------------------------ 6.2/25.1 MB 9.6 MB/s eta 0:00:02
#    ----------- ----------------------------
using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-4.0.2-py3-none-win_amd64.whl (82 kB)
#    ---------------------------------------- 0.0/82.9 kB ? eta -:--:--
#    ---------------------------------------- 82.9/82.9 kB 2.3 MB/s eta 0:00:00
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB 1.6 MB/s eta 0:00:00
# Downloading narwhals-1.8.2-py3-none-any.whl (167 kB)
#    ---------------------------------------- 0.0/167.7 kB ? eta -:--:--
#    ---------------------------------------- 167.7/167.7 kB 5.1 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, toml, smmap, pyarrow, protobuf, narwhals, mdurl, cachetools, blinker, pydeck, markdown-it-py, gitdb, rich, gitpython, altair, streamlit
# Successfully installed altair-5.4.1 blinker-1.8.2 cachetools-5.5.0 gitdb-4.0.11 gitpython-3.1.43 markdown-it-py-3.0.0 mdurl-0.1.2 narwhals-1.8.2 protobuf-5.28.2 pyarrow-17.0.0 pydeck-0.9.1 rich-13.8.1 smmap-5.0.1 streamlit-1.38.0 toml-0.10.2 watchdog-4.0.2
# DEPRECATION: celery 4.4.0 has a non-standard dependency specifier pytz>dev. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of celery or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
                                                                                                                                
st.title("StreamLab Options")

option = st.selectbox(
    "Automate Office Task",
    ("Convert PDF", "Send Mail", "Interactive Excel", "Download Project Structure Template", "Create PowerPoint from Charts", "Mail Merge")
)

if option == "Convert PDF":
    st.subheader("Convert PDF")
    uploaded_file = st.file_uploader("Upload a PDF file", type="pdf")
    if uploaded_file is not None:
        converted_pdf = convert_pdf(uploaded_file)
        st.download_button("Download Converted PDF", converted_pdf, file_name="converted.pdf")

elif option == "Send Mail":
    st.subheader("Send Mail")
    sender_email = st.text_input("Sender Email")
    receiver_email = st.text_input("Receiver Email")
    subject = st.text_input("Subject")
    message = st.text_area("Message")
    
    if st.button("Send Email"):
        send_email(sender_email, receiver_email, subject, message)

elif option == "Interactive Excel":
    st.subheader("Interactive Excel")
    excel_file = st.file_uploader("Upload an Excel file", type="xlsx")
    if excel_file is not None:
        interactive_excel(excel_file)

elif option == "Download Project Structure Template":
    st.subheader("Download Project Structure Excel Template")
    template = create_project_structure_template()
    st.download_button("Download Project Structure Template", template, file_name="project_structure_template.xlsx")

elif option == "Create PowerPoint from Charts":
    st.subheader("Create PowerPoint Presentation from Charts")
    if st.button("Generate PowerPoint"):
        ppt_path = create_powerpoint()
        st.success(f"PowerPoint presentation created: {ppt_path}")
        st.download_button("Download PowerPoint Presentation", open(ppt_path, 'rb'), file_name=os.path.basename(ppt_path))

elif option == "Mail Merge":
    st.subheader("Mail Merge Documents")
    if st.button("Perform Mail Merge"):
        mail_merge()
        st.success("Mail merge completed. Check the output folder for documents.")
